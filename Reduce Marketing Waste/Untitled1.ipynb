# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/train.csv')

# %%
df.head()
# Out:
#    Deal_title                      Lead_name               Industry  \
# 0  TitleM5DZY  Davis, Perkins and Bishop Inc            Restaurants
# 1  TitleKIW18                 Bender PLC LLC  Construction Services
# 2  TitleFXSDN          Carter-Henry and Sons      Hospitals/Clinics
# 3  TitlePSK4Y                 Garcia Ltd Ltd            Real Estate
# 4  Title904GV               Lee and Sons PLC     Financial Services
#
#   Deal_value Weighted_amount Date_of_creation      Pitch  \
# 0    320506$      2067263.7$       2020-03-29  Product_2
# 1     39488$       240876.8$       2019-07-10  Product_2
# 2    359392$      2407926.4$       2019-07-27  Product_1
# 3     76774$       468321.4$       2021-01-30  Product_2
# 4    483896$             NaN       2019-05-22  Product_2
#
#              Contact_no             Lead_revenue Fund_category  ...  \
# 0          607.447.7883         50 - 100 Million    Category 2  ...
# 1          892-938-9493  500 Million - 1 Billion    Category 4  ...
# 2          538.748.2271  500 Million - 1 Billion    Category 4  ...
# 3   (692)052-1389x75188  500 Million - 1 Billion    Category 3  ...
# 4  001-878-814-6134x015         50 - 100 Million    Category 3  ...
#
#                 Designation                 Lead_POC_email  \
# 0  Executive Vice President       charlenewerner@davis.com
# 1    Chairman/CEO/President          terrylogan@bender.com
# 2      SVP/General Counsel   arielhamilton@carterhenry.com
# 3   CEO/Co-Founder/Chairman          erinwilson@garcia.com
# 4  Executive Vice President         mr.christopher@lee.com
#
#             Hiring_candidate_role      Lead_source Level_of_meeting  \
# 0            Community pharmacist          Website          Level 3
# 1          Recruitment consultant           Others          Level 1
# 2          Health service manager  Marketing Event          Level 1
# 3  Therapist, speech and language    Contact Email          Level 2
# 4                   Media planner          Website          Level 2
#
#                   Last_lead_update               Internal_POC  \
# 0                         No track           Davis,Sharrice A
# 1  Did not hear back after Level 1             Brown,Maxine A
# 2                                ?  Georgakopoulos,Vasilios T
# 3  Did not hear back after Level 1             Brown,Maxine A
# 4                       Up-to-date              Thomas,Lori E
#
#                        Resource Internal_rating Success_probability
# 0                           NaN               3                73.6
# 1                            No               5                58.9
# 2                            No               4                68.8
# 3  We have all the requirements               1                64.5
# 4                            No               4                62.4
#
# [5 rows x 23 columns]

# %%
df.drop('Lead_name', axis=1, inplace=True)
df.drop('Deal_title', axis=1, inplace=True)
df.drop('Contact_no', axis=1, inplace=True)

# %%
df.head()
# Out:
#                 Industry Deal_value Weighted_amount Date_of_creation  \
# 0            Restaurants    320506$      2067263.7$       2020-03-29
# 1  Construction Services     39488$       240876.8$       2019-07-10
# 2      Hospitals/Clinics    359392$      2407926.4$       2019-07-27
# 3            Real Estate     76774$       468321.4$       2021-01-30
# 4     Financial Services    483896$             NaN       2019-05-22
#
#        Pitch             Lead_revenue Fund_category Geography  \
# 0  Product_2         50 - 100 Million    Category 2       USA
# 1  Product_2  500 Million - 1 Billion    Category 4     India
# 2  Product_1  500 Million - 1 Billion    Category 4       USA
# 3  Product_2  500 Million - 1 Billion    Category 3       USA
# 4  Product_2         50 - 100 Million    Category 3     India
#
#                       Location         POC_name               Designation  \
# 0           Killeen-Temple, TX  Charlene Werner  Executive Vice President
# 1                       Ratlam            rakhi    Chairman/CEO/President
# 2  Albany-Schenectady-Troy, NY   Ariel Hamilton      SVP/General Counsel
# 3   Mount Vernon-Anacortes, WA      Erin Wilson   CEO/Co-Founder/Chairman
# 4                      Shimoga           kavita  Executive Vice President
#
#                   Lead_POC_email           Hiring_candidate_role  \
# 0       charlenewerner@davis.com            Community pharmacist
# 1          terrylogan@bender.com          Recruitment consultant
# 2  arielhamilton@carterhenry.com          Health service manager
# 3          erinwilson@garcia.com  Therapist, speech and language
# 4         mr.christopher@lee.com                   Media planner
#
#        Lead_source Level_of_meeting                 Last_lead_update  \
# 0          Website          Level 3                         No track
# 1           Others          Level 1  Did not hear back after Level 1
# 2  Marketing Event          Level 1                                ?
# 3    Contact Email          Level 2  Did not hear back after Level 1
# 4          Website          Level 2                       Up-to-date
#
#                 Internal_POC                      Resource  Internal_rating  \
# 0           Davis,Sharrice A                           NaN                3
# 1             Brown,Maxine A                            No                5
# 2  Georgakopoulos,Vasilios T                            No                4
# 3             Brown,Maxine A  We have all the requirements                1
# 4              Thomas,Lori E                            No                4
#
#    Success_probability
# 0                 73.6
# 1                 58.9
# 2                 68.8
# 3                 64.5
# 4                 62.4

# %%
df['Deal_value'].fillna('247839$', inplace=True)

# %%
df['Industry'].fillna('Banks', inplace=True)
df['Weighted_amount'].fillna('1452260.0168$', inplace=True)

# %%
df['Weighted_amount'] = df['Weighted_amount'].apply(lambda a: np.float64(a.split('$')[0])).mean()

# %%
df['Location'].fillna('Unknown', inplace=True)

# %%
df['Last_lead_update'].fillna('Not Known', inplace=True)

# %%
df['Resource'].value_counts().sort_values(ascending=True).head(10)
# Out:
# Cannot deliver                  1113
# Yes                             1130
# Deliverable                     1131
# Not enough                      1145
# We have all the requirements    1160
# No                              1179
# Name: Resource, dtype: int64

# %%
df['Resource'].fillna('Not known', inplace=True)

# %%
def fill_geography(location):
    if(location.find(',')!=-1):
        return 'USA'
    else:
        return 'India'
    
df['Geography'] = df['Location'].apply(fill_geography)

# %%
df.drop('POC_name', axis=1, inplace=True)

# %%
df.head()
# Out:
#                 Industry Deal_value  Weighted_amount Date_of_creation  \
# 0            Restaurants    320506$     1.561071e+06       2020-03-29
# 1  Construction Services     39488$     1.561071e+06       2019-07-10
# 2      Hospitals/Clinics    359392$     1.561071e+06       2019-07-27
# 3            Real Estate     76774$     1.561071e+06       2021-01-30
# 4     Financial Services    483896$     1.561071e+06       2019-05-22
#
#        Pitch             Lead_revenue Fund_category Geography  \
# 0  Product_2         50 - 100 Million    Category 2       USA
# 1  Product_2  500 Million - 1 Billion    Category 4     India
# 2  Product_1  500 Million - 1 Billion    Category 4       USA
# 3  Product_2  500 Million - 1 Billion    Category 3       USA
# 4  Product_2         50 - 100 Million    Category 3     India
#
#                       Location               Designation  \
# 0           Killeen-Temple, TX  Executive Vice President
# 1                       Ratlam    Chairman/CEO/President
# 2  Albany-Schenectady-Troy, NY      SVP/General Counsel
# 3   Mount Vernon-Anacortes, WA   CEO/Co-Founder/Chairman
# 4                      Shimoga  Executive Vice President
#
#                   Lead_POC_email           Hiring_candidate_role  \
# 0       charlenewerner@davis.com            Community pharmacist
# 1          terrylogan@bender.com          Recruitment consultant
# 2  arielhamilton@carterhenry.com          Health service manager
# 3          erinwilson@garcia.com  Therapist, speech and language
# 4         mr.christopher@lee.com                   Media planner
#
#        Lead_source Level_of_meeting                 Last_lead_update  \
# 0          Website          Level 3                         No track
# 1           Others          Level 1  Did not hear back after Level 1
# 2  Marketing Event          Level 1                                ?
# 3    Contact Email          Level 2  Did not hear back after Level 1
# 4          Website          Level 2                       Up-to-date
#
#                 Internal_POC                      Resource  Internal_rating  \
# 0           Davis,Sharrice A                     Not known                3
# 1             Brown,Maxine A                            No                5
# 2  Georgakopoulos,Vasilios T                            No                4
# 3             Brown,Maxine A  We have all the requirements                1
# 4              Thomas,Lori E                            No                4
#
#    Success_probability
# 0                 73.6
# 1                 58.9
# 2                 68.8
# 3                 64.5
# 4                 62.4

# %%
df['Deal_value'] = df['Deal_value'].apply(lambda a: np.int64(a.split('$')[0]))

# %%
df['Pitch'] = df['Pitch'].apply(lambda a: np.int64(a.split('_')[1]))
df['Fund_category'] = df['Fund_category'].apply(lambda a: np.int64(a.split(' ')[1]))
df.drop(['Location', 'Lead_POC_email'], axis=1, inplace=True)
df['Level_of_meeting'] = df['Level_of_meeting'].apply(lambda a: np.int64(a.split(' ')[1]))

# %%
def impute_lead_revenue(revenue):
    temp = revenue.split('-')
    value1 = temp[0].split(' ')[0]
    if(temp[1].split(' ')[2] == 'Billion'):
        value2 = np.int64(temp[1].split(' ')[1])*1000
    else:
        value2 = temp[1].split(' ')[1]
    
    return np.int64(value2)-np.int64(value1)

df['Lead_revenue'] = df['Lead_revenue'].apply(impute_lead_revenue)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7007 entries, 0 to 7006
# Data columns (total 17 columns):
# Industry                 7007 non-null object
# Deal_value               7007 non-null int64
# Weighted_amount          7007 non-null float64
# Date_of_creation         7007 non-null object
# Pitch                    7007 non-null int64
# Lead_revenue             7007 non-null int64
# Fund_category            7007 non-null int64
# Geography                7007 non-null object
# Designation              7007 non-null object
# Hiring_candidate_role    7007 non-null object
# Lead_source              7007 non-null object
# Level_of_meeting         7007 non-null int64
# Last_lead_update         7007 non-null object
# Internal_POC             7007 non-null object
# Resource                 7007 non-null object
# Internal_rating          7007 non-null int64
# Success_probability      7007 non-null float64
# dtypes: float64(2), int64(6), object(9)
# memory usage: 930.7+ KB

# %%
df['Hiring_candidate_role'].unique().shape
# Out:
# (639,)
